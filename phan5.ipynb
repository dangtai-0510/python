# %%
# ===========================================
# PHAN 5.1 - TOM TAT DU AN
# ===========================================

print()
print("="*70)
print("5.1 TOM TAT DU AN")
print("="*70)
print()

# a. Tong quan KPI

tong_doanh_thu = df_orders["gia_tri"].sum()

so_don_done = len(df_orders[df_orders["trang_thai"] == "done"])

AOV = df_orders[df_orders["trang_thai"] == "done"]["gia_tri"].mean()

ty_le_huy = len(df_orders[df_orders["trang_thai"] == "cancel"]) * 100 / len(df_orders)

print("a. Tong quan KPI")
print()

print("Tong doanh thu:")
print(round(tong_doanh_thu,2))
print()

print("So don hoan thanh:")
print(so_don_done)
print()

print("AOV (Average Order Value):")
print(round(AOV,2))
print()

print("Ty le huy don:")
print(round(ty_le_huy,2),"%")
print()

# b. Diem noi bat

print("b. Diem noi bat")
print()

top3_kenh = phan_tich_kenh.head(3)

print("Top 3 kenh ban hieu qua nhat:")
print(top3_kenh["tong_doanh_thu"])
print()

print("Kenh ban kem hieu qua nhat:")
print(phan_tich_kenh.tail(1)["tong_doanh_thu"])
print()

top3_khu_vuc = dong_gop_khu_vuc.head(3)

print("Top 3 khu vuc dong gop doanh thu cao nhat:")
print(top3_khu_vuc)
print()

print("Khu vuc dong gop doanh thu thap nhat:")
print(dong_gop_khu_vuc.tail(1))
print()

thang_max = doanh_thu_thang.loc[doanh_thu_thang["doanh_thu"].idxmax()]

print("Thang but pha nhat:")
print(thang_max["thang"])
print("Doanh thu:")
print(round(thang_max["doanh_thu"],2))
print()

# c. Van de phat hien

print("c. Van de phat hien")
print()

print("Van de 1:")
print("Ty le huy don hien tai la",round(ty_le_huy,2),"%, can tiep tuc giam.")
print()

kenh_thap = phan_tich_kenh.index[-1]

print("Van de 2:")
print("Kenh ban co doanh thu thap nhat la:")
print(kenh_thap)
print()

print("Van de 3:")
print("Doanh thu giua cac thang chua on dinh, co su bien dong.")

# %%
# ===========================================
# PHAN 5.2
# NHAN XET VA DE XUAT
# ===========================================

print()
print("="*70)
print("5.2 NHAN XET VA DE XUAT CAI TIEN")
print("="*70)
print()

print("De xuat 1 (Uu tien cao)")
print()

print("Can tap trung dau tu vao kenh:")
print(top3_kenh.index[0])
print()

print("Ly do:")
print("Day la kenh co tong doanh thu cao nhat.")
print()

print("Hanh dong:")
print("Tang ngan sach quang cao va chuong trinh khuyen mai.")
print()

print("Muc tieu:")
print("Tang doanh thu them khoang 10% trong quy tiep theo.")
print()

print("-"*60)
print()

print("De xuat 2 (Uu tien trung binh)")
print()

print("Can cai thien kenh:")
print(kenh_thap)
print()

print("Ly do:")
print("Day la kenh co tong doanh thu thap nhat.")
print()

print("Hanh dong:")
print("Kiem tra quy trinh ban hang va tang chuong trinh uu dai.")
print()

print("Muc tieu:")
print("Tang doanh thu cua kenh len it nhat 15%.")
print()

print("-"*60)
print()

print("De xuat 3 (Uu tien trung binh)")
print()

print("Can giam ty le huy don hien tai:")
print(round(ty_le_huy,2),"%")
print()

print("Hanh dong:")
print("Xac nhan don hang som hon va nhac khach truoc khi giao.")
print()

print("Muc tieu:")
print("Dua ty le huy don xuong duoi 5%.")
print()

print("-"*60)
print()

print("Tong ket:")
print("Nen uu tien dau tu vao cac kenh mang lai doanh thu cao.")
print("Can cai thien cac kenh co doanh thu thap.")
print("Dong thoi giam ty le huy don de nang cao hieu qua kinh doanh.")
